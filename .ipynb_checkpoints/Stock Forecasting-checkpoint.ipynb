# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_csv_data = pd.read_csv("AAPL.csv")

# %%
df = raw_csv_data.copy()

# %%
df.head()
# Out:
#          date     open     high      low    close    volume  unadjustedVolume  \
# 0  2014-01-09  71.6912  71.6991  70.1900  70.3432  69905199           9986457
# 1  2014-01-10  70.7773  70.9045  69.6341  69.8740  76320664          10902952
# 2  2014-01-13  69.4767  71.1274  69.4728  70.2398  94860843          13551549
# 3  2014-01-14  70.5663  71.6820  70.4928  71.6374  83734371          11962053
# 4  2014-01-15  72.5722  73.4481  72.3284  73.0757  98472619          14067517
#
#      change  changePercent     vwap       label  changeOverTime
# 0 -0.910039         -1.277  70.8314   Jan 9, 14        0.000000
# 1 -0.469243         -0.667  69.9929  Jan 10, 14       -0.006670
# 2  0.365800          0.524  69.9468  Jan 13, 14       -0.001470
# 3  1.397600          1.990  76.3121  Jan 14, 14        0.018398
# 4  1.438300          2.008  73.0992  Jan 15, 14        0.038845

# %%
df.tail()
# Out:
#             date    open      high     low   close    volume  \
# 1253  2019-01-02  154.89  158.8500  154.23  157.92  37039737
# 1254  2019-01-03  143.98  145.7200  142.00  142.19  91312195
# 1255  2019-01-04  144.53  148.5499  143.80  148.26  58607070
# 1256  2019-01-07  148.70  148.8300  145.90  147.93  54777764
# 1257  2019-01-08  149.56  151.8200  148.52  150.75  41025314
#
#       unadjustedVolume  change  changePercent      vwap  label  changeOverTime
# 1253          37039737    0.18          0.114  156.9710  Jan 2        1.244993
# 1254          91312195  -15.73         -9.961  143.5353  Jan 3        1.021375
# 1255          58607070    6.07          4.269  146.8337  Jan 4        1.107666
# 1256          54777764   -0.33         -0.223  147.3460  Jan 7        1.102975
# 1257          41025314    2.82          1.906  150.1092  Jan 8        1.143064

# %%
df.describe()
# Out:
#               open         high          low        close        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    127.020244   128.115159   125.908309   127.037249  4.284843e+07
# std      39.036252    39.395210    38.652854    39.021704  2.353540e+07
# min      64.923300    65.755800    64.709600    65.526600  1.147592e+07
# 25%      98.070875    99.763175    97.312975    98.371450  2.660238e+07
# 50%     114.043100   114.595250   113.149650   114.059600  3.698370e+07
# 75%     156.017900   157.466300   154.708850   156.068000  5.214835e+07
# max     229.977600   232.658200   228.981100   231.263100  2.668336e+08
#
#        unadjustedVolume       change  changePercent         vwap  \
# count      1.258000e+03  1258.000000    1258.000000  1258.000000
# mean       3.741102e+07     0.063193       0.071507   127.061466
# std        2.051157e+07     2.105054       1.542402    39.006943
# ...

# %%
df.isna().sum()
# Out:
# date                0
# open                0
# high                0
# low                 0
# close               0
# volume              0
# unadjustedVolume    0
# change              0
# changePercent       0
# vwap                0
# label               0
# changeOverTime      0
# dtype: int64

# %%
df.plot(y = ["close", "open"], figsize = (20,5), x = "date")
plt.title('AAPL trend', size = 20)
# Out:
# Text(0.5, 1.0, 'AAPL trend')

# %%
df.set_index("date")
# Out:
#                 open      high       low     close     volume  \
# date
# 2014-01-09   71.6912   71.6991   70.1900   70.3432   69905199
# 2014-01-10   70.7773   70.9045   69.6341   69.8740   76320664
# 2014-01-13   69.4767   71.1274   69.4728   70.2398   94860843
# 2014-01-14   70.5663   71.6820   70.4928   71.6374   83734371
# 2014-01-15   72.5722   73.4481   72.3284   73.0757   98472619
# 2014-01-16   72.7532   73.0088   72.3310   72.6680   57471330
# 2014-01-17   72.3048   72.3821   70.7865   70.8875  108426689
# 2014-01-21   70.9294   72.1199   70.8547   71.9888   82255544
# 2014-01-22   72.2307   73.0665   71.8236   72.3087   95219334
# 2014-01-23   72.1029   72.9630   71.4298   72.9210  100978346
# 2014-01-24   72.6352   72.8476   71.4224   71.5955  108384437
# 2014-01-27   72.1199   72.7401   71.5535   72.1763  144219152
# 2014-01-28   66.7037   67.5219   65.8266   66.4074  266833581
# 2014-01-29   66.0731   66.5215   65.3743   65.6535  125942796
# ...

# %%
df.describe()
# Out:
#               open         high          low        close        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    127.020244   128.115159   125.908309   127.037249  4.284843e+07
# std      39.036252    39.395210    38.652854    39.021704  2.353540e+07
# min      64.923300    65.755800    64.709600    65.526600  1.147592e+07
# 25%      98.070875    99.763175    97.312975    98.371450  2.660238e+07
# 50%     114.043100   114.595250   113.149650   114.059600  3.698370e+07
# 75%     156.017900   157.466300   154.708850   156.068000  5.214835e+07
# max     229.977600   232.658200   228.981100   231.263100  2.668336e+08
#
#        unadjustedVolume       change  changePercent         vwap  \
# count      1.258000e+03  1258.000000    1258.000000  1258.000000
# mean       3.741102e+07     0.063193       0.071507   127.061466
# std        2.051157e+07     2.105054       1.542402    39.006943
# ...

# %%
#making changes to new_branch
